# %% [markdown]
# ##  **N-Grams**
#
# ---
#
# ### **What is an N-Gram?**
#
# An **N-gram** is a sequence of **N consecutive words** from a text.
#
# * `Unigram` = single word
# * `Bigram` = pair of 2 words
# * `Trigram` = group of 3 words
# * and so on...
#
# ---
#
# ### **Why Use N-Grams?**
#
# * To **capture word combinations** and some context/structure.
# * Helps models understand **phrases**, not just single words.
# * Useful for tasks like **text classification, sentiment analysis,** and **language modeling**.
#
# ---
#
# ### **Example:**
#
# Text: `"I love cats"`
#
# * **Unigrams**: `["I", "love", "cats"]`
# * **Bigrams**: `["I love", "love cats"]`
# * **Trigrams**: `["I love cats"]`
#
# ---
#
# ### **Summary**
#
# | Aspect    | Details                                               |
# | --------- | ----------------------------------------------------- |
# | Purpose   | Capture word sequences (context)                      |
# | Pros      | Adds meaning, better than BoW alone                   |
# | Cons      | Increases vector size, sparse data                    |
# | Use cases | Text classification, sentiment analysis, autocomplete |
#
# ---

# %%
import pandas as pd

# %%
df = pd.DataFrame({'text': ['people watch campusx', 'campusx watch campusx', 'people write comment', 'campusx write comment'], 'output': [1, 1, 0, 0]})
df
# Out:
#                     text  output
# 0   people watch campusx       1
# 1  campusx watch campusx       1
# 2   people write comment       0
# 3  campusx write comment       0

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Initialize CountVectorizer
cv= CountVectorizer(ngram_range=(2, 2))

# %%
BOW= cv.fit_transform(df['text']) ## All Vocab found out

# %%
print(cv.vocabulary_)
# Out:
# {'people watch': 2, 'watch campusx': 4, 'campusx watch': 0, 'people write': 3, 'write comment': 5, 'campusx write': 1}

# %%
print(BOW[0].toarray())
# Out:
# [[0 0 1 0 1 0]]

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Initialize CountVectorizer
cv= CountVectorizer(ngram_range=(3, 3))

# %%
BOW= cv.fit_transform(df['text']) ## All Vocab found out

# %%
print(cv.vocabulary_)
# Out:
# {'people watch campusx': 2, 'campusx watch campusx': 0, 'people write comment': 3, 'campusx write comment': 1}

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Initialize CountVectorizer
cv= CountVectorizer(ngram_range=(1, 2))

# %%
BOW= cv.fit_transform(df['text']) ## All Vocab found out

# %%
print(cv.vocabulary_)
# Out:
# {'people': 4, 'watch': 7, 'campusx': 0, 'people watch': 5, 'watch campusx': 8, 'campusx watch': 1, 'write': 9, 'comment': 3, 'people write': 6, 'write comment': 10, 'campusx write': 2}

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Initialize CountVectorizer
cv= CountVectorizer(ngram_range=(1, 3))

# %%
BOW= cv.fit_transform(df['text']) ## All Vocab found out

# %%
print(cv.vocabulary_)
# Out:
# {'people': 6, 'watch': 11, 'campusx': 0, 'people watch': 7, 'watch campusx': 12, 'people watch campusx': 8, 'campusx watch': 1, 'campusx watch campusx': 2, 'write': 13, 'comment': 5, 'people write': 9, 'write comment': 14, 'people write comment': 10, 'campusx write': 3, 'campusx write comment': 4}

# %% [markdown]
# ### **Lets Try With The Same Dataset**

# %%
import pandas as pd

# %%
spam_classifier= pd.read_csv("spam.csv")

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Initialize CountVectorizer
cv = CountVectorizer(
    lowercase=True,
    stop_words='english',
    token_pattern='[a-zA-Z]+',
    ngram_range=(2,2),
)

# %%
BOW= cv.fit_transform(spam_classifier['Message']) ## All Vocab found out

# %%
cv.vocabulary_
# Out:
# {'jurong point': 11615,
#  'point crazy': 18409,
#  'crazy available': 4377,
#  'available bugis': 1102,
#  'bugis n': 2414,
#  'n great': 15924,
#  'great world': 9168,
#  'world la': 28425,
#  'la e': 12373,
#  'e buffet': 6217,
#  'buffet cine': 2410,
#  'cine got': 3405,
#  'got amore': 8869,
#  'amore wat': 544,
#  'ok lar': 17028,
#  'lar joking': 12452,
#  'joking wif': 11567,
#  'wif u': 27948,
#  'u oni': 25930,
#  'free entry': 7689,
#  'entry wkly': 6638,
#  'wkly comp': 28158,
#  'comp win': 3934,
#  'win fa': 27997,
#  'fa cup': 6909,
#  'cup final': 4489,
#  'final tkts': 7275,
#  'tkts st': 24839,
#  'st text': 22546,
#  'text fa': 23929,
#  'fa receive': 6910,
#  'receive entry': 19484,
#  'entry question': 6633,
#  'question std': 19013,
#  'std txt': 22700,
#  'txt rate': 25577,
#  'rate t': 19235,
#  't c': 23293,
#  'c s': 2606,
#  's apply': 20207,
#  'apply s': 744,
#  'u dun': 25755,
#  'dun say': 6168,
#  'say early': 20791,
#  'early hor': 6306,
#  'hor u': 10616,
#  'u c': 25693,
#  'c say': 2607,
#  'nah don': 16003,
#  'don t': 5817,
#  't think': 23476,
#  'think goes': 24357,
#  'goes usf': 8498,
#  'usf lives': 26650,
#  'freemsg hey': 7796,
#  'hey darling': 10108,
#  'darling s': 4803,
#  's week': 20535,
#  'week s': 27715,
#  's word': 20538,
#  'word d': 28296,
#  'd like': 4597,
#  'like fun': 13011,
#  'fun tb': 8044,
#  'tb ok': 23662,
#  'ok xxx': 17101,
#  'xxx std': 28693,
#  'std chgs': 22697,
#  'chgs send': 3300,
#  'send rcv': 21181,
#  'brother like': 2339,
#  'like speak': 13094,
#  'speak treat': 22384,
#  'treat like': 25306,
#  'like aids': 12971,
#  'aids patent': 379,
#  'request melle': 19790,
#  'melle melle': 14879,
#  'melle oru': 14880,
#  'oru minnaminunginte': 17353,
#  'minnaminunginte nurungu': 15098,
#  'nurungu vettam': 16759,
#  'vettam set': 26854,
#  'set callertune': 21337,
#  'callertune callers': 2681,
#  'callers press': 2680,
#  'press copy': 18663,
#  'copy friends': 4183,
#  'friends callertune': 7881,
#  'winner valued': 28056,
#  'valued network': 26762,
#  'network customer': 16286,
#  'customer selected': 4527,
#  'selected receivea': 21068,
#  'receivea prize': 19495,
#  'prize reward': 18762,
#  'reward claim': 19872,
#  'claim claim': 3424,
#  'claim code': 3425,
#  'code kl': 3606,
#  'kl valid': 12132,
#  'valid hours': 26750,
#  'mobile months': 15337,
#  'months u': 15551,
#  'u r': 25962,
#  'r entitled': 19105,
#  'entitled update': 6627,
#  'update latest': 26322,
#  'latest colour': 12557,
#  'colour mobiles': 3684,
#  'mobiles camera': 15366,
#  'camera free': 2748,
#  'free mobile': 7715,
#  'mobile update': 15356,
#  'update free': 26320,
#  'm gonna': 14165,
#  'gonna home': 8686,
#  'home soon': 10473,
#  'soon don': 22181,
#  't want': 23498,
#  'want talk': 27343,
#  'talk stuff': 23599,
#  'stuff anymore': 22910,
#  'anymore tonight': 687,
#  'tonight k': 25115,
#  'k ve': 11960,
#  've cried': 26790,
#  'cried today': 4422,
#  'chances win': 3088,
#  'win cash': 27996,
#  'cash pounds': 2957,
#  'pounds txt': 18554,
#  'txt csh': 25547,
#  'csh send': 4452,
#  'send cost': 21135,
#  'cost p': 4271,
#  'p day': 17438,
#  'day days': 4903,
#  'days tsandcs': 5028,
#  'tsandcs apply': 25461,
#  'apply reply': 743,
#  'reply hl': 19730,
#  'hl info': 10305,
#  'urgent won': 26556,
#  'won week': 28213,
#  'week free': 27696,
#  'free membership': 7709,
#  'membership prize': 14890,
#  'prize jackpot': 18756,
#  'jackpot txt': 11402,
#  'txt word': 25600,
#  'word claim': 28293,
#  'claim t': 3445,
#  'c www': 2620,
#  'www dbuk': 28592,
#  'dbuk net': 5035,
#  'net lccltd': 16267,
#  'lccltd pobox': 12606,
#  'pobox ldnw': 18389,
#  'ldnw rw': 12613,
#  've searching': 26817,
#  'searching right': 20995,
#  'right words': 19945,
#  'words thank': 28316,
#  'thank breather': 24084,
#  'breather promise': 2259,
#  'promise wont': 18883,
#  'wont help': 28264,
#  'help granted': 10051,
#  'granted fulfil': 9094,
#  'fulfil promise': 8025,
#  'promise wonderful': 18882,
#  'wonderful blessing': 28229,
#  'blessing times': 1944,
#  'date sunday': 4861,
#  'xxxmobilemovieclub use': 28696,
#  'use credit': 26585,
#  'credit click': 4398,
#  'click wap': 3525,
#  'wap link': 27411,
#  'link txt': 13182,
#  'txt message': 25562,
#  'message click': 14925,
#  'click http': 3522,
#  'http wap': 10774,
#  'wap xxxmobilemovieclub': 27415,
#  'xxxmobilemovieclub com': 28695,
#  'com n': 3707,
#  'n qjkgighjjgcbl': 15952,
#  'oh k': 16925,
#  'k m': 11927,
#  'm watching': 14296,
#  'eh u': 6444,
#  'u remember': 25974,
#  'remember spell': 19634,
#  'spell yes': 22426,
#  'yes did': 28950,
#  'did v': 5422,
#  'v naughty': 26719,
#  'naughty make': 16058,
#  'make v': 14455,
#  'v wet': 26733,
#  'fine s': 7325,
#  's way': 20532,
#  'way u': 27611,
#  'u feel': 25773,
#  'feel s': 7136,
#  'way gota': 27574,
#  'gota b': 9037,
#  'england v': 6566,
#  'v macedonia': 26715,
#  'macedonia dont': 14319,
#  'dont miss': 5863,
#  'miss goals': 15174,
#  'goals team': 8461,
#  'team news': 23698,
#  'news txt': 16392,
#  'txt ur': 25597,
#  'ur national': 26466,
#  'national team': 16046,
#  'team england': 23696,
#  'england try': 6565,
#  'try wales': 25433,
#  'wales scotland': 27140,
#  'scotland txt': 20948,
#  'txt poboxox': 25572,
#  'poboxox w': 18401,
#  'w wq': 27011,
#  'seriously spell': 21295,
#  'm going': 14164,
#  'going try': 8628,
#  'try months': 25421,
#  'months ha': 15547,
#  'ha ha': 9504,
#  'ha joking': 9505,
#  'pay lar': 17682,
#  'lar da': 12444,
#  'da stock': 4706,
#  'stock comin': 22729,
#  'aft finish': 272,
#  'finish lunch': 7353,
#  'lunch str': 14032,
#  'str lor': 22840,
#  'lor ard': 13636,
#  'ard smth': 801,
#  'smth lor': 22068,
#  'lor u': 13690,
#  'u finish': 25779,
#  'finish ur': 7360,
#  'ur lunch': 26451,
#  'ffffffffff alright': 7210,
#  'alright way': 513,
#  'way meet': 27582,
#  'meet sooner': 14832,
#  'just forced': 11701,
#  'forced eat': 7546,
#  'eat slice': 6373,
#  'slice m': 21907,
#  'm really': 14242,
#  'really hungry': 19401,
#  'hungry tho': 10821,
#  'tho sucks': 24507,
#  'sucks mark': 23001,
#  'mark getting': 14570,
#  'getting worried': 8345,
#  'worried knows': 28449,
#  'knows m': 12330,
#  'm sick': 14253,
#  'sick turn': 21653,
#  'turn pizza': 25491,
#  'pizza lol': 18092,
#  'lol convincing': 13477,
#  'did catch': 5355,
#  'catch bus': 2981,
#  'bus frying': 2450,
#  'frying egg': 7971,
#  'egg did': 6434,
#  'did make': 5387,
#  'make tea': 14447,
#  'tea eating': 23675,
#  'eating mom': 6396,
#  'mom s': 15414,
#  's left': 20363,
#  'left dinner': 12706,
#  'dinner feel': 5529,
#  'feel love': 7130,
#  'm amp': 14091,
#  'amp packing': 574,
#  'packing car': 17501,
#  'car ll': 2811,
#  'll let': 13336,
#  'let know': 12810,
#  'know s': 12270,
#  's room': 20445,
#  'ahhh work': 370,
#  'work vaguely': 28378,
#  'vaguely remember': 26736,
#  'remember does': 19622,
#  'does feel': 5686,
#  'feel like': 7129,
#  'like lol': 13040,
#  'wait s': 27063,
#  's clear': 20244,
#  'clear sure': 3508,
#  'sure sarcastic': 23161,
#  'sarcastic s': 20695,
#  's x': 20545,
#  'x doesn': 28634,
#  'doesn t': 5704,
#  'want live': 27302,
#  'yeah got': 28826,
#  'got v': 9026,
#  'v apologetic': 26697,
#  'apologetic n': 716,
#  'n fallen': 15912,
#  'fallen actin': 6974,
#  'actin like': 136,
#  'like spoilt': 13096,
#  'spoilt child': 22474,
#  'child got': 3330,
#  'got caught': 8887,
#  'caught till': 2990,
#  'till won': 24659,
#  'won t': 28210,
#  't doing': 23317,
#  'doing badly': 5744,
#  'badly cheers': 1414,
#  'k tell': 11950,
#  'fear fainting': 7098,
#  'fainting housework': 6961,
#  'housework just': 10721,
#  'just did': 11683,
#  'did quick': 5397,
#  'quick cuppa': 19025,
#  'thanks subscription': 24145,
#  'subscription ringtone': 22989,
#  'ringtone uk': 19982,
#  'uk mobile': 26169,
#  'mobile charged': 15313,
#  'charged month': 3139,
#  'month confirm': 15516,
#  'confirm replying': 4025,
#  'replying yes': 19780,
#  'yes reply': 28983,
#  'reply charged': 19715,
#  'yup ok': 29158,
#  'ok home': 17020,
#  'home look': 10450,
#  'look timings': 13588,
#  'timings msg': 24803,
#  'msg xuhui': 15762,
#  'xuhui going': 28678,
#  'going learn': 8568,
#  'learn nd': 12627,
#  'nd lesson': 16070,
#  'oops ll': 17221,
#  'know roommate': 12268,
#  'roommate s': 20080,
#  'letter b': 12845,
#  'b car': 1230,
#  'u decide': 25727,
#  'hello s': 10031,
#  's did': 20268,
#  'did saturday': 5401,
#  'saturday just': 20732,
#  'just texting': 11825,
#  'texting d': 24030,
#  'd decided': 4580,
#  'decided tomo': 5150,
#  'tomo m': 25018,
#  'm trying': 14282,
#  'trying invite': 25446,
#  'pls ahead': 18262,
#  'ahead watts': 369,
#  'watts just': 27547,
#  'just wanted': 11845,
#  'wanted sure': 27380,
#  'sure great': 23137,
#  'great weekend': 9167,
#  'weekend abiola': 27741,
#  'did forget': 5368,
#  'forget tell': 7570,
#  'tell want': 23817,
#  'want need': 27315,
#  'need crave': 16134,
#  'crave love': 4369,
#  'love sweet': 13893,
#  'sweet arabian': 23212,
#  'arabian steed': 786,
#  'steed mmmmmm': 22709,
#  'mmmmmm yummy': 15282,
#  'rodger burns': 20034,
#  'burns msg': 2442,
#  'msg tried': 15754,
#  'tried reply': 25329,
#  'reply sms': 19753,
#  'sms free': 22039,
#  'free nokia': 7724,
#  'nokia mobile': 16587,
#  'mobile free': 15324,
#  'free camcorder': 7672,
#  'camcorder delivery': 2726,
#  'delivery tomorrow': 5219,
#  'great hope': 9129,
#  'hope like': 10561,
#  'like man': 13050,
#  'man endowed': 14514,
#  'endowed lt': 6538,
#  'lt gt': 13980,
#  'gt inches': 9269,
#  'calls messages': 2709,
#  'messages missed': 14974,
#  'missed calls': 15206,
#  'didn t': 5432,
#  't hep': 23354,
#  'hep b': 10082,
#  'b immunisation': 1254,
#  'immunisation nigeria': 11095,
#  'fair going': 6962,
#  'yeah hopefully': 28829,
#  'hopefully tyler': 10601,
#  'tyler t': 25626,
#  't maybe': 23391,
#  'maybe ask': 14669,
#  'ask bit': 894,
#  'u don': 25746,
#  't know': 23368,
#  'know stubborn': 12283,
#  'stubborn didn': 22885,
#  'want hospital': 27284,
#  'hospital kept': 10637,
#  'kept telling': 12033,
#  'telling mark': 23831,
#  'mark m': 14571,
#  'm weak': 14298,
#  'weak sucker': 27625,
#  'sucker hospitals': 22997,
#  'hospitals weak': 10641,
#  'weak suckers': 27626,
#  'thinked time': 24425,
#  'time saw': 24742,
#  'saw class': 20760,
#  'gram usually': 9084,
#  'usually runs': 26678,
#  'runs like': 20181,
#  'like lt': 13045,
#  'gt half': 9262,
#  'half eighth': 9604,
#  'eighth smarter': 6448,
#  'smarter gets': 21959,
#  'gets second': 8288,
#  'second gram': 21010,
#  'gram lt': 9082,
#  'k fyi': 11910,
#  'fyi x': 8078,
#  'x ride': 28644,
#  'ride early': 19897,
#  'early tomorrow': 6319,
#  'tomorrow morning': 25045,
#  'morning s': 15589,
#  's crashing': 20253,
#  'crashing place': 4366,
#  'place tonight': 18128,
#  'wow realized': 28510,
#  'realized embarassed': 19373,
#  'embarassed accomodations': 6488,
#  'accomodations thought': 104,
#  'thought liked': 24536,
#  'liked doing': 13131,
#  'doing best': 5745,
#  'best happy': 1703,
#  'happy cave': 9715,
#  'cave m': 3012,
#  'm sorry': 14260,
#  'sorry didn': 22229,
#  't don': 23318,
#  't m': 23385,
#  'sorry offered': 22268,
#  'offered m': 16855,
#  'sorry room': 22274,
#  'room embarassing': 20060,
#  'sms ac': 22033,
#  'ac sptv': 74,
#  'sptv new': 22511,
#  'new jersey': 16336,
#  'jersey devils': 11462,
#  'devils detroit': 5324,
#  'detroit red': 5317,
#  'red wings': 19539,
#  'wings play': 28047,
#  'play ice': 18201,
#  'ice hockey': 10900,
#  'hockey correct': 10351,
#  'correct incorrect': 4194,
#  'incorrect end': 11147,
#  'end reply': 6521,
#  'reply end': 19723,
#  'end sptv': 6524,
#  'know mallika': 12233,
#  'mallika sherawat': 14505,
#  'sherawat did': 21465,
#  'did yesterday': 5429,
#  'yesterday lt': 29022,
#  'lt url': 13983,
#  'url gt': 26566,
#  'congrats year': 4045,
#  'year special': 28891,
#  'special cinema': 22391,
#  'cinema pass': 3407,
#  'pass c': 17636,
#  'c suprman': 2610,
#  'suprman v': 23117,
#  'v matrix': 26716,
#  'matrix starwars': 14645,
#  'starwars free': 22647,
#  'free bx': 7669,
#  'bx ip': 2558,
#  'ip pm': 11306,
#  'pm dont': 18357,
#  'sorry ll': 22257,
#  'll later': 13334,
#  'later meeting': 12537,
#  'tell reached': 23792,
#  'yes gauti': 28955,
#  'gauti sehwag': 8199,
#  'sehwag odi': 21062,
#  'odi series': 16836,
#  'gonna pick': 8697,
#  'pick burger': 17976,
#  'burger way': 2436,
#  'way home': 27576,
#  'home t': 10478,
#  't pain': 23410,
#  'pain killing': 17527,
#  'ha good': 9503,
#  'good joke': 8764,
#  'joke girls': 11555,
#  'girls situation': 8413,
#  'situation seekers': 21802,
#  'checking iq': 3259,
#  'sorry roommates': 22275,
#  'roommates took': 20084,
#  'took forever': 25142,
#  'forever ok': 7552,
#  'ok come': 16990,
#  'lar double': 12446,
#  'double check': 5925,
#  'check wif': 3247,
#  'wif da': 27935,
#  'da hair': 4662,
#  'hair dresser': 9584,
#  'dresser said': 6006,
#  'said wun': 20649,
#  'wun cut': 28576,
#  'cut v': 4542,
#  'v short': 26726,
#  'short said': 21580,
#  'said cut': 20597,
#  'cut look': 4536,
#  'look nice': 13584,
#  'valued customer': 26758,
#  'customer pleased': 4526,
#  'pleased advise': 18243,
#  'advise following': 250,
#  'following recent': 7495,
#  'recent review': 19504,
#  'review mob': 19868,
#  'mob awarded': 15298,
#  'awarded bonus': 1160,
#  'bonus prize': 2027,
#  'today song': 24929,
#  'song dedicated': 22157,
#  'dedicated day': 5163,
#  'day song': 4975,
#  'song u': 22160,
#  'u dedicate': 25728,
#  'dedicate send': 5162,
#  'send ur': 21201,
#  'ur valuable': 26524,
#  'valuable frnds': 26753,
#  'frnds rply': 7954,
#  'urgent ur': 26553,
#  'ur awarded': 26355,
#  'awarded complimentary': 1163,
#  'complimentary trip': 3982,
#  'trip eurodisinc': 25334,
#  'eurodisinc trav': 6708,
#  'trav aco': 25295,
#  'aco entry': 133,
#  'entry claim': 6630,
#  'claim txt': 3448,
#  'txt dis': 25549,
#  'dis morefrmmob': 5581,
#  'morefrmmob shracomorsglsuplt': 15563,
#  'shracomorsglsuplt ls': 21623,
#  'ls aj': 13972,
#  'did hear': 5375,
#  'hear new': 9910,
#  'new divorce': 16328,
#  'divorce barbie': 5635,
#  'barbie comes': 1473,
#  'comes ken': 3868,
#  'ken s': 12028,
#  's stuff': 20485,
#  'plane month': 18166,
#  'month end': 15521,
#  'wah lucky': 27021,
#  'lucky man': 14001,
#  'man save': 14530,
#  'save money': 20749,
#  'money hee': 15468,
#  'finished class': 7368,
#  'hi babe': 10179,
#  'babe im': 1311,
#  'im home': 11041,
#  'home wanna': 10491,
#  'wanna xx': 27245,
#  'k k': 11921,
#  'k did': 11903,
#  'did performed': 5393,
#  'waiting machan': 27095,
#  'machan free': 14321,
#  'thats cool': 24187,
#  'cool gentleman': 4151,
#  'gentleman treat': 8270,
#  'treat dignity': 25304,
#  'dignity respect': 5509,
#  'like peoples': 13069,
#  'peoples shy': 17770,
#  'shy pa': 21638,
#  'does operate': 5694,
#  'operate lt': 17246,
#  'looking job': 13612,
#  'job ta': 11509,
#  'ta s': 23515,
#  's earn': 20280,
#  'did just': 5380,
#  'just ah': 11646,
#  'ok way': 17094,
#  'home hi': 10439,
#  'hi hi': 10206,
#  'place man': 18111,
#  'yup stop': 29164,
#  'later don': 12521,
#  't network': 23405,
#  'network urgnt': 16294,
#  'urgnt sms': 26561,
#  'real u': 19359,
#  'u getting': 25794,
#  'getting yo': 8346,
#  'yo need': 29073,
#  'need tickets': 16215,
#  'tickets jacket': 24611,
#  'jacket m': 11401,
#  'm used': 14287,
#  'used multis': 26632,
#  'yes started': 28990,
#  'started send': 22626,
#  'send requests': 21183,
#  'requests make': 19791,
#  'make pain': 14428,
#  'pain came': 17519,
#  'came m': 2739,
#  'm bed': 14102,
#  'bed double': 1596,
#  'double coins': 5926,
#  'coins factory': 3620,
#  'factory gotta': 6952,
#  'gotta cash': 9047,
#  'cash nitros': 2954,
#  'really tonight': 19432,
#  'tonight babe': 25107,
#  'ela kano': 6452,
#  'kano il': 11989,
#  'il download': 10966,
#  'download come': 5941,
#  'come wen': 3852,
#  'wen ur': 27822,
#  'ur free': 26409,
#  'yeah don': 28821,
#  't stand': 23461,
#  'stand close': 22570,
#  'close tho': 3539,
#  'tho ll': 24505,
#  'll catch': 13297,
#  'sorry pain': 22270,
#  'pain ok': 17531,
#  'ok meet': 17038,
#  'meet night': 14819,
#  'night spent': 16490,
#  'spent late': 22445,
#  'late afternoon': 12471,
#  'afternoon casualty': 286,
#  'casualty means': 2974,
#  'means haven': 14739,
#  'haven t': 9822,
#  't y': 23508,
#  'y stuff': 28737,
#  'stuff moro': 22926,
#  'moro includes': 15604,
#  'includes time': 11138,
#  'time sheets': 24745,
#  'sheets sorry': 21460,
#  'smile pleasure': 21982,
#  'pleasure smile': 18251,
#  'smile pain': 21981,
#  'pain smile': 17533,
#  'smile trouble': 21991,
#  'trouble pours': 25356,
#  'pours like': 18557,
#  'like rain': 13076,
#  'rain smile': 19180,
#  'smile sum': 21987,
#  'sum hurts': 23029,
#  'hurts u': 10862,
#  'u smile': 26015,
#  'smile becoz': 21968,
#  'becoz loves': 1590,
#  'loves u': 13950,
#  'u smiling': 26016,
#  'customer service': 4528,
#  'service representative': 21323,
#  'representative pm': 19785,
#  'pm won': 18379,
#  'won guaranteed': 28202,
#  'guaranteed cash': 9361,
#  'cash prize': 2958,
#  'havent planning': 9833,
#  'planning buy': 18179,
#  'buy later': 2511,
#  'later check': 12518,
#  'check lido': 3230,
#  'lido got': 12881,
#  'got e': 8903,
#  'e afternoon': 6213,
#  'afternoon u': 299,
#  'finish work': 7363,
#  'free ringtone': 7742,
#  'ringtone waiting': 19983,
#  'waiting collected': 27084,
#  'collected simply': 3656,
#  'simply text': 21707,
#  'text password': 23974,
#  'password mix': 17654,
#  'mix verify': 15257,
#  'verify usher': 26847,
#  'usher britney': 26655,
#  'britney fml': 2317,
#  'fml po': 7482,
#  'po box': 18382,
#  'box mk': 2157,
#  'mk h': 15259,
#  'h ppw': 9498,
#  'watching telugu': 27525,
#  'telugu movie': 23844,
#  'movie wat': 15658,
#  'wat abt': 27443,
#  'abt u': 66,
#  'finish loads': 7352,
#  'loads loans': 13423,
#  'loans pay': 13439,
#  'hi wk': 10249,
#  'wk ok': 28140,
#  'ok hols': 17019,
#  'hols yes': 10395,
#  'yes bit': 28943,
#  'bit run': 1899,
#  'run forgot': 20162,
#  'forgot hairdressers': 7587,
#  'hairdressers appointment': 9595,
#  'appointment need': 751,
#  'need home': 16152,
#  'home n': 10459,
#  'n shower': 15965,
#  'shower does': 21600,
#  'does cause': 5677,
#  'cause prob': 3003,
#  'prob u': 18778,
#  'cup coffee': 4488,
#  'coffee animation': 3612,
#  't text': 23474,
#  'text anymore': 23904,
#  'anymore say': 686,
#  'okay ur': 17119,
#  'ur price': 26486,
#  'price long': 18701,
#  'long legal': 13545,
#  'legal wen': 12732,
#  'wen pick': 27820,
#  'pick y': 18009,
#  'y u': 28740,
#  'u ave': 25664,
#  'ave x': 1124,
#  'x ams': 28631,
#  'ams xx': 600,
#  'm looking': 14195,
#  'looking car': 13605,
#  'car buy': 2799,
#  'buy gone': 2505,
#  'gone driving': 8654,
#  'driving test': 6069,
#  'wow right': 28511,
#  'right didn': 19905,
#  't mean': 23392,
#  'mean guess': 14713,
#  'guess gave': 9395,
#  'gave boston': 8200,
#  'boston men': 2108,
#  'men changed': 14895,
#  'changed search': 3113,
#  'search location': 20984,
#  'location nyc': 13447,
#  'nyc changed': 16786,
#  'changed cuz': 3108,
#  'cuz signin': 4561,
#  'signin page': 21670,
#  'page says': 17506,
#  'says boston': 20866,
#  'umma life': 26200,
#  'life vava': 12938,
#  'vava umma': 26778,
#  'umma love': 26201,
#  'love lot': 13856,
#  'lot dear': 13728,
#  'thanks lot': 24131,
#  'lot wishes': 13753,
#  'wishes birthday': 28098,
#  'birthday thanks': 1864,
#  'thanks making': 24134,
#  'making birthday': 14480,
#  'birthday truly': 1866,
#  'truly memorable': 25383,
#  'aight ll': 390,
#  'll hit': 13326,
#  'hit cash': 10281,
#  'ip address': 11304,
#  'address test': 216,
#  'test considering': 23878,
#  'considering computer': 4067,
#  'computer isn': 3990,
#  'isn t': 11339,
#  't minecraft': 23396,
#  'minecraft server': 15089,
#  'know grumpy': 12207,
#  'grumpy old': 9213,
#  'old people': 17151,
#  'people mom': 17751,
#  'mom like': 15411,
#  'like better': 12975,
#  'better lying': 1752,
#  'lying play': 14081,
#  'play jokes': 18204,
#  'dont worry': 5907,
#  'worry guess': 28462,
#  'guess s': 9415,
#  's busy': 20232,
#  'plural noun': 18320,
#  'noun research': 16662,
#  'going dinner': 8541,
#  'dinner msg': 5534,
#  'm ok': 14218,
#  'ok wif': 17097,
#  'wif cos': 27934,
#  'cos like': 4225,
#  'like try': 13118,
#  'try new': 25423,
#  'new things': 16361,
#  'things scared': 24321,
#  'scared u': 20886,
#  'dun like': 6163,
#  'like mah': 13048,
#  'mah cos': 14352,
#  'cos u': 4252,
#  'u said': 25988,
#  'said loud': 20616,
#  'gent trying': 8264,
#  'trying contact': 25439,
#  'contact weekends': 4093,
#  'weekends draw': 27758,
#  'draw shows': 5974,
#  'shows won': 21622,
#  'won prize': 28209,
#  'prize guaranteed': 18755,
#  'guaranteed claim': 9362,
#  'code k': 3605,
#  'k valid': 11959,
#  'valid hrs': 26752,
#  'hrs ppm': 10762,
#  'wa ur': 27017,
#  'ur openin': 26472,
#  'openin sentence': 17243,
#  'sentence formal': 21279,
#  'formal m': 7605,
#  'm fine': 14153,
#  'fine juz': 7316,
#  'juz tt': 11881,
#  'tt m': 25469,
#  'm eatin': 14142,
#  'eatin n': 6391,
#  'n puttin': 15951,
#  'puttin weight': 18969,
#  'weight haha': 27785,
#  'haha anythin': 9536,
#  'anythin special': 692,
#  'special happened': 22393,
#  'entered cabin': 6617,
#  'cabin pa': 2624,
#  'pa said': 17489,
#  'said happy': 20607,
#  'happy b': 9709,
#  'b day': 1233,
#  'day boss': 4891,
#  'boss felt': 2104,
#  'felt special': 7193,
#  'special askd': 22390,
#  'askd lunch': 955,
#  'lunch lunch': 14025,
#  'lunch invited': 14022,
#  'invited apartment': 11293,
#  'apartment went': 710,
#  'winner u': 28055,
#  'u specially': 26023,
#  'specially selected': 22413,
#  'selected receive': 21067,
#  'receive holiday': 19485,
#  'holiday flights': 10381,
#  'flights speak': 7448,
#  'speak live': 22378,
#  'live operator': 13261,
#  'operator claim': 17247,
#  'claim p': 3438,
#  'p min': 17447,
#  'goodo yes': 8851,
#  'yes speak': 28989,
#  'speak friday': 22376,
#  'friday egg': 7837,
#  'egg potato': 6435,
#  'potato ratio': 18535,
#  'ratio tortilla': 19241,
#  'tortilla needed': 25175,
#  'hmm uncle': 10323,
#  'uncle just': 26218,
#  'just informed': 11731,
#  'informed s': 11206,
#  's paying': 20413,
#  'paying school': 17705,
#  'school directly': 20912,
#  'directly pls': 5564,
#  'pls buy': 18266,
#  'buy food': 2504,
#  'private account': 18743,
#  'account statement': 120,
#  'statement shows': 22652,
#  'shows unredeemed': 21621,
#  'unredeemed bonus': 26296,
#  'bonus points': 2026,
#  'points claim': 18419,
#  'claim identifier': 3429,
#  'identifier code': 10938,
#  'code expires': 3604,
#  'urgent mobile': 26549,
#  'mobile awarded': 15309,
#  'bonus caller': 2024,
#  'caller prize': 2678,
#  'prize final': 18754,
#  'final try': 7276,
#  'try contact': 25408,
#  'contact u': 4091,
#  'u landline': 25857,
#  'landline box': 12411,
#  'box wr': 2167,
#  'wr c': 28519,
#  'c ppm': 2601,
#  'new address': 16317,
#  'address apples': 203,
#  'apples pairs': 732,
#  'pairs malarky': 17543,
#  'todays voda': 24952,
#  'voda numbers': 26945,
#  'numbers ending': 16752,
#  'ending selected': 6534,
#  'receive award': 19480,
#  'award match': 1152,
#  'match quoting': 14612,
#  'quoting claim': 19082,
#  'code standard': 3609,
#  'standard rates': 22573,
#  'rates app': 19238,
#  'going sao': 8602,
#  'sao mu': 20688,
#  'mu today': 15803,
#  'predict wat': 18624,
#  'wat time': 27474,
#  'time ll': 24718,
#  'll finish': 13308,
#  'finish buying': 7344,
#  'good stuff': 8810,
#  'just know': 11738,
#  'know yetunde': 12320,
#  'yetunde hasn': 29033,
#  ...}

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Initialize CountVectorizer
cv = CountVectorizer(
    lowercase=True,
    stop_words='english',
    token_pattern='[a-zA-Z]+',
    ngram_range=(3,3),
)

# %%
BOW= cv.fit_transform(spam_classifier['Message']) ## All Vocab found out

# %%
print(cv.vocabulary_)
# Out:
# {'jurong point crazy': 11566, 'point crazy available': 18684, 'crazy available bugis': 4180, 'available bugis n': 1022, 'bugis n great': 2272, 'n great world': 16214, 'great world la': 9084, 'world la e': 29089, 'la e buffet': 12420, 'e buffet cine': 6191, 'buffet cine got': 2268, 'cine got amore': 3217, 'got amore wat': 8758, 'ok lar joking': 17338, 'lar joking wif': 12501, 'joking wif u': 11521, 'wif u oni': 28601, 'free entry wkly': 7542, 'entry wkly comp': 6599, 'wkly comp win': 28824, 'comp win fa': 3734, 'win fa cup': 28648, 'fa cup final': 6834, 'cup final tkts': 4288, 'final tkts st': 7172, 'tkts st text': 25102, 'st text fa': 22756, 'text fa receive': 24181, 'fa receive entry': 6835, 'receive entry question': 19734, 'entry question std': 6592, 'question std txt': 19239, 'std txt rate': 22886, 'txt rate t': 25835, 'rate t c': 19485, 't c s': 23448, 'c s apply': 2443, 's apply s': 20398, 'u dun say': 26081, 'dun say early': 6122, 'say early hor': 21045, 'early hor u': 6285, 'hor u c': 10612, 'u c say': 25985, 'nah don t': 16286, 'don t think': 5748, 't think goes': 23714, 'think goes usf': 24606, 'goes usf lives': 8345, 'freemsg hey darling': 7672, 'hey darling s': 10064, 'darling s week': 4604, 's week s': 20786, 'week s word': 28374, 's word d': 20789, 'word d like': 28980, 'd like fun': 4389, 'like fun tb': 13067, 'fun tb ok': 7905, 'tb ok xxx': 23918, 'ok xxx std': 17446, 'xxx std chgs': 29355, 'std chgs send': 22884, 'chgs send rcv': 3119, 'brother like speak': 2202, 'like speak treat': 13147, 'speak treat like': 22609, 'treat like aids': 25562, 'like aids patent': 13025, 'request melle melle': 20035, 'melle melle oru': 15192, 'melle oru minnaminunginte': 15193, 'oru minnaminunginte nurungu': 17680, 'minnaminunginte nurungu vettam': 15386, 'nurungu vettam set': 17051, 'vettam set callertune': 27472, 'set callertune callers': 21611, 'callertune callers press': 2541, 'callers press copy': 2540, 'press copy friends': 18912, 'copy friends callertune': 3973, 'winner valued network': 28709, 'valued network customer': 27358, 'network customer selected': 16553, 'customer selected receivea': 4317, 'selected receivea prize': 21315, 'receivea prize reward': 19746, 'prize reward claim': 19008, 'reward claim claim': 20107, 'claim claim code': 3235, 'claim code kl': 3237, 'code kl valid': 3410, 'kl valid hours': 12173, 'mobile months u': 15634, 'months u r': 15840, 'u r entitled': 26418, 'r entitled update': 19333, 'entitled update latest': 6586, 'update latest colour': 26898, 'latest colour mobiles': 12608, 'colour mobiles camera': 3481, 'mobiles camera free': 15670, 'camera free mobile': 2606, 'free mobile update': 7573, 'mobile update free': 15659, 'm gonna home': 14449, 'gonna home soon': 8538, 'home soon don': 10452, 'soon don t': 22399, 'don t want': 5756, 't want talk': 23762, 'want talk stuff': 27975, 'talk stuff anymore': 23861, 'stuff anymore tonight': 23081, 'anymore tonight k': 652, 'tonight k ve': 25386, 'k ve cried': 12018, 've cried today': 27385, 'chances win cash': 2922, 'win cash pounds': 28644, 'cash pounds txt': 2793, 'pounds txt csh': 18817, 'txt csh send': 25800, 'csh send cost': 4260, 'send cost p': 21380, 'cost p day': 4071, 'p day days': 17756, 'day days tsandcs': 4707, 'days tsandcs apply': 4847, 'tsandcs apply reply': 25715, 'apply reply hl': 701, 'reply hl info': 19971, 'urgent won week': 27179, 'won week free': 28900, 'week free membership': 28348, 'free membership prize': 7563, 'membership prize jackpot': 15204, 'prize jackpot txt': 19003, 'jackpot txt word': 11374, 'txt word claim': 25872, 'word claim t': 28976, 'claim t c': 3264, 't c www': 23449, 'c www dbuk': 2472, 'www dbuk net': 29251, 'dbuk net lccltd': 4855, 'net lccltd pobox': 16533, 'lccltd pobox ldnw': 12661, 'pobox ldnw rw': 18662, 've searching right': 27427, 'searching right words': 21239, 'right words thank': 20162, 'words thank breather': 29000, 'thank breather promise': 24340, 'breather promise wont': 2133, 'promise wont help': 1912 ...
