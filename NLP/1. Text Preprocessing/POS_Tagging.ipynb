# %% [markdown]
# ### **POS Tagging**
#
# ---
#
# ### **What is POS Tagging?**
#
# **POS (Part-of-Speech) tagging** means labeling each word in a sentence with its **grammatical role**, like noun, verb, adjective, etc.
#
# 🔸 Example:
#
# ```text
# The dog barked loudly.
# ```
#
# * The → Determiner
# * dog → Noun
# * barked → Verb
# * loudly → Adverb
#
# ---
#
# ### **Why is it Needed?**
#
# * Helps NLP models **understand the structure** of a sentence
# * Required for accurate **lemmatization**
# * Useful in **named entity recognition**, **sentiment analysis**, and **question answering**
#
# ---
#
# ### **Common POS Tags :**
#
# | Tag   | Meaning        | Example       |
# | ----- | -------------- | ------------- |
# | NOUN  | Noun           | book, dog     |
# | VERB  | Verb           | run, eat      |
# | ADJ   | Adjective      | big, fast     |
# | ADV   | Adverb         | quickly, very |
# | PRON  | Pronoun        | he, they      |
# | AUX   | Auxiliary Verb | is, was       |
# | ADP   | Preposition    | in, on, at    |
# | DET   | Determiner     | the, a, this  |
# | PUNCT | Punctuation    | . , ? !       |
#
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### **How to Do It with spaCy:**

# %%
import spacy

# Load the model
nlp = spacy.load("en_core_web_sm")

# Input text
text = "The children are playing in the park."

# Process the text
doc = nlp(text)

# %%
doc
# Out:
# The children are playing in the park.

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %%
doc.text
# Out:
# 'The children are playing in the park.'

# %%
type(doc.text)
# Out:
# str

# %%
doc[2]
# Out:
# are

# %%
doc[0].pos_
# Out:
# 'DET'

# %%
doc[2].pos_
# Out:
# 'AUX'

# %%
doc[7].pos_
# Out:
# 'PUNCT'

# %%
doc[2].tag_
# Out:
# 'VBP'

# %%
spacy.explain('VBP')
# Out:
# 'verb, non-3rd person singular present'

# %%
doc
# Out:
# The children are playing in the park.

# %%
for word in doc:
    print(word, "->", word.pos_)
# Out:
# The -> DET
# children -> NOUN
# are -> AUX
# playing -> VERB
# in -> ADP
# the -> DET
# park -> NOUN
# . -> PUNCT

# %%
spacy.explain('ADP')
# Out:
# 'adposition'

# %%
for word in doc:
    print(word, "->", word.pos_,word.tag_ , spacy.explain(word.tag_))
# Out:
# The -> DET DT determiner
# children -> NOUN NNS noun, plural
# are -> AUX VBP verb, non-3rd person singular present
# playing -> VERB VBG verb, gerund or present participle
# in -> ADP IN conjunction, subordinating or preposition
# the -> DET DT determiner
# park -> NOUN NN noun, singular or mass
# . -> PUNCT . punctuation mark, sentence closer

# %%
from spacy import displacy

# %%
displacy.render(doc)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="28d3e8a149ef4a95a6acc14afacd4de9-0" class="displacy" width="1275" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">children</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">playing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">park.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-28d3e8a149ef4a95a6acc14afacd4de9-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-28d3e8a149ef4a95a6acc14afacd4de9-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-28d3e8a149ef4a95a6acc14afacd4de9-0-1" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-28d3e8a149ef4a95a6acc14afacd4de9-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-28d3e8a149ef4a95a6acc14afacd4de9-0-2" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-28d3e8a149ef4a95a6acc14afacd4de9-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-28d3e8a149ef4a95a6acc14afacd4de9-0-3" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-28d3e8a149ef4a95a6acc14afacd4de9-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,179.0 L753.0,167.0 737.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-28d3e8a149ef4a95a6acc14afacd4de9-0-4" stroke-width="2px" d="M945,177.0 C945,89.5 1095.0,89.5 1095.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-28d3e8a149ef4a95a6acc14afacd4de9-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,179.0 L937,167.0 953,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-28d3e8a149ef4a95a6acc14afacd4de9-0-5" stroke-width="2px" d="M770,177.0 C770,2.0 1100.0,2.0 1100.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-28d3e8a149ef4a95a6acc14afacd4de9-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1100.0,179.0 L1108.0,167.0 1092.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
# Input text
text = """She said, "I am tired." Then she left. Prof. Ahmed works at A.I. Lab."""

# Process the text
doc1 = nlp(text)

# %%
displacy.render(doc1)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3368f9ceac9f4994933e81dc136cb3cd-0" class="displacy" width="2500" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">She</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">said, &quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">am</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">tired.&quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">Then</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">she</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">left.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Prof.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Ahmed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">works</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">A.I.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">Lab.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3368f9ceac9f4994933e81dc136cb3cd-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3368f9ceac9f4994933e81dc136cb3cd-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3368f9ceac9f4994933e81dc136cb3cd-0-1" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3368f9ceac9f4994933e81dc136cb3cd-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3368f9ceac9f4994933e81dc136cb3cd-0-2" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3368f9ceac9f4994933e81dc136cb3cd-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ccomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,179.0 L583.0,167.0 567.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3368f9ceac9f4994933e81dc136cb3cd-0-3" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3368f9ceac9f4994933e81dc136cb3cd-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,179.0 L753.0,167.0 737.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3368f9ceac9f4994933e81dc136cb3cd-0-4" stroke-width="2px" d="M945,177.0 C945,2.0 1275.0,2.0 1275.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3368f9ceac9f4994933e81dc136cb3cd-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,179.0 L937,167.0 953,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3368f9ceac9f4994933e81dc136cb3cd-0-5" stroke-width="2px" d="M1120,177.0 C1120,89.5 1270.0,89.5 1270.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3368f9ceac9f4994933e81dc136cb3cd-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,179.0 L1112,167.0 1128,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3368f9ceac9f4994933e81dc136cb3cd-0-6" stroke-width="2px" d="M1470,177.0 C1470,89.5 1620.0,89.5 1620.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3368f9ceac9f4994933e81dc136cb3cd-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1470,179.0 L1462,167.0 1478,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3368f9ceac9f4994933e81dc136cb3cd-0-7" stroke-width="2px" d=

# %% [markdown]
# **More Practices**

# %%
import spacy

# Load the model
nlp = spacy.load("en_core_web_sm")

# Input text
text1 = "I saw a man with a telescope."
text2= "The telescope was used by the man I saw."

# Process the text
doc1 = nlp(text1)
doc2 = nlp(text2)

# %%
for word in doc1:
    print(word, "-->" , word.pos_ )
# Out:
# I --> PRON
# saw --> VERB
# a --> DET
# man --> NOUN
# with --> ADP
# a --> DET
# telescope --> NOUN
# . --> PUNCT

# %%
from spacy import displacy

# %%
displacy.render(doc1)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="be119251e185428f8961152ef09e96d1-0" class="displacy" width="1275" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">saw</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">man</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">telescope.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-be119251e185428f8961152ef09e96d1-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-be119251e185428f8961152ef09e96d1-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-be119251e185428f8961152ef09e96d1-0-1" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-be119251e185428f8961152ef09e96d1-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-be119251e185428f8961152ef09e96d1-0-2" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-be119251e185428f8961152ef09e96d1-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,179.0 L583.0,167.0 567.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-be119251e185428f8961152ef09e96d1-0-3" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-be119251e185428f8961152ef09e96d1-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,179.0 L753.0,167.0 737.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-be119251e185428f8961152ef09e96d1-0-4" stroke-width="2px" d="M945,177.0 C945,89.5 1095.0,89.5 1095.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-be119251e185428f8961152ef09e96d1-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,179.0 L937,167.0 953,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-be119251e185428f8961152ef09e96d1-0-5" stroke-width="2px" d="M770,177.0 C770,2.0 1100.0,2.0 1100.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-be119251e185428f8961152ef09e96d1-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1100.0,179.0 L1108.0,167.0 1092.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
displacy.render(doc2)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c560a9aabbf44c9992b17f2e10b03dd0-0" class="displacy" width="1625" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">telescope</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">used</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">man</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">saw.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c560a9aabbf44c9992b17f2e10b03dd0-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c560a9aabbf44c9992b17f2e10b03dd0-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c560a9aabbf44c9992b17f2e10b03dd0-0-1" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c560a9aabbf44c9992b17f2e10b03dd0-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c560a9aabbf44c9992b17f2e10b03dd0-0-2" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c560a9aabbf44c9992b17f2e10b03dd0-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">auxpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c560a9aabbf44c9992b17f2e10b03dd0-0-3" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c560a9aabbf44c9992b17f2e10b03dd0-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">agent</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,179.0 L753.0,167.0 737.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c560a9aabbf44c9992b17f2e10b03dd0-0-4" stroke-width="2px" d="M945,177.0 C945,89.5 1095.0,89.5 1095.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c560a9aabbf44c9992b17f2e10b03dd0-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,179.0 L937,167.0 953,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c560a9aabbf44c9992b17f2e10b03dd0-0-5" stroke-width="2px" d="M770,177.0 C770,2.0 1100.0,2.0 1100.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c560a9aabbf44c9992b17f2e10b03dd0-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1100.0,179.0 L1108.0,167.0 1092.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c560a9aabbf44c9992b17f2e10b03dd0-0-6" stroke-width="2px" d="M1295,177.0 C1295,89.5 1445.0,89.5 1445.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c560a9aabbf44c9992b17f2e10b03dd0-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,179.0 L1287,167.0 1303,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c560a9aabbf44c9992b17f2e10b03dd0-0-7" stroke-width="2px" d="M1120,177.0 C1120,2.0 1450.0,2.0 1450.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c560a9aabbf44c9992b17f2e10b03dd0-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">relcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1450.0,179.0 L1458.0,167.0 1442.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# > dep_ tells you what job each word is doing in the sentence.

# %%
for word in doc1:
    print(word, "-->" , word.pos_ , "|" , word.tag_ , "-->" , spacy.explain(word.tag_))
# Out:
# I --> PRON | PRP --> pronoun, personal
# saw --> VERB | VBD --> verb, past tense
# a --> DET | DT --> determiner
# man --> NOUN | NN --> noun, singular or mass
# with --> ADP | IN --> conjunction, subordinating or preposition
# a --> DET | DT --> determiner
# telescope --> NOUN | NN --> noun, singular or mass
# . --> PUNCT | . --> punctuation mark, sentence closer

# %%
paragaph = """Data Solution-360 is a consulting company and online learning platform focused on data science, 
artificial intelligence, machine learning, and data analytics etc . 
They offer online courses, consulting services, and job-ready bootcamps to help individuals gain skills and knowledge in 
these areas. Their goal is to make data science accessible and empower individuals to leverage data for better decisions 
and careers. """

# %%
docx= nlp(paragaph)

# %%
for words in docx:
    print(words, "-->" , words.pos_ , "|" , words.tag_ ,"-->" , spacy.explain(words.tag_))
# Out:
# Data --> NOUN | NNS --> noun, plural
# Solution-360 --> VERB | VBP --> verb, non-3rd person singular present
# is --> AUX | VBZ --> verb, 3rd person singular present
# a --> DET | DT --> determiner
# consulting --> VERB | VBG --> verb, gerund or present participle
# company --> NOUN | NN --> noun, singular or mass
# and --> CCONJ | CC --> conjunction, coordinating
# online --> ADJ | JJ --> adjective (English), other noun-modifier (Chinese)
# learning --> VERB | VBG --> verb, gerund or present participle
# platform --> NOUN | NN --> noun, singular or mass
# focused --> VERB | VBN --> verb, past participle
# on --> ADP | IN --> conjunction, subordinating or preposition
# data --> NOUN | NN --> noun, singular or mass
# science --> NOUN | NN --> noun, singular or mass
# , --> PUNCT | , --> punctuation mark, comma
#
#  --> SPACE | _SP --> whitespace
# artificial --> ADJ | JJ --> adjective (English), other noun-modifier (Chinese)
# intelligence --> NOUN | NN --> noun, singular or mass
# , --> PUNCT | , --> punctuation mark, comma
# machine --> NOUN | NN --> noun, singular or mass
# learning --> NOUN | NN --> noun, singular or mass
# , --> PUNCT | , --> punctuation mark, comma
# and --> CCONJ | CC --> conjunction, coordinating
# data --> NOUN | NN --> noun, singular or mass
# analytics --> NOUN | NNS --> noun, plural
# etc --> X | FW --> foreign word
# . --> PUNCT | . --> punctuation mark, sentence closer
#
#  --> SPACE | _SP --> whitespace
# They --> PRON | PRP --> pronoun, personal
# offer --> VERB | VBP --> verb, non-3rd person singular present
# online --> ADJ | JJ --> adjective (English), other noun-modifier (Chinese)
# courses --> NOUN | NNS --> noun, plural
# , --> PUNCT | , --> punctuation mark, comma
# consulting --> VERB | VBG --> verb, gerund or present participle
# services --> NOUN | NNS --> noun, plural
# , --> PUNCT | , --> punctuation mark, comma
# and --> CCONJ | CC --> conjunction, coordinating
# job --> NOUN | NN --> noun, singular or mass
# - --> PUNCT | HYPH --> punctuation mark, hyphen
# ready --> ADJ | JJ --> adjective (English), other noun-modifier (Chinese)
# bootcamps --> NOUN | NNS --> noun, plural
# to --> PART | TO --> infinitival "to"
# help --> VERB | VB --> verb, base form
# individuals --> NOUN | NNS --> noun, plural
# gain --> VERB | VB --> verb, base form
# skills --> NOUN | NNS --> noun, plural
# and --> CCONJ | CC --> conjunction, coordinating
# knowledge --> NOUN | NN --> noun, singular or mass
# in --> ADP | IN --> conjunction, subordinating or preposition
#
#  --> SPACE | _SP --> whitespace
# these --> DET | DT --> determiner
# areas --> NOUN | NNS --> noun, plural
# . --> PUNCT | . --> punctuation mark, sentence closer
# Their --> PRON | PRP$ --> pronoun, possessive
# goal --> NOUN | NN --> noun, singular or mass
# is --> AUX | VBZ --> verb, 3rd person singular present
# to --> PART | TO --> infinitival "to"
# make --> VERB | VB --> verb, base form
# data --> NOUN | NNS --> noun, plural
# science --> NOUN | NN --> noun, singular or mass
# accessible --> ADJ | JJ --> adjective (English), other noun-modifier (Chinese)
# and --> CCONJ | CC --> conjunction, coordinating
# empower --> VERB | VB --> verb, base form
# individuals --> NOUN | NNS --> noun, plural
# to --> PART | TO --> infinitival "to"
# leverage --> VERB | VB --> verb, base form
# data --> NOUN | NNS --> noun, plural
# for --> ADP | IN --> conjunction, subordinating or preposition
# better --> ADJ | JJR --> adjective, comparative
# decisions --> NOUN | NNS --> noun, plural
#
#  --> SPACE | _SP --> whitespace
# and --> CCONJ | CC --> conjunction, coordinating
# careers --> NOUN | NNS --> noun, plural
# . --> PUNCT | . --> punctuation mark, sentence closer

# %%
for words in docx:
    if words.pos_ not in ["SPACE","PUNCT","X"]:
        print(words, "-->" , words.pos_ , "|" , words.tag_ ,"-->" , spacy.explain(words.tag_))
# Out:
# Data --> NOUN | NNS --> noun, plural
# Solution-360 --> VERB | VBP --> verb, non-3rd person singular present
# is --> AUX | VBZ --> verb, 3rd person singular present
# a --> DET | DT --> determiner
# consulting --> VERB | VBG --> verb, gerund or present participle
# company --> NOUN | NN --> noun, singular or mass
# and --> CCONJ | CC --> conjunction, coordinating
# online --> ADJ | JJ --> adjective (English), other noun-modifier (Chinese)
# learning --> VERB | VBG --> verb, gerund or present participle
# platform --> NOUN | NN --> noun, singular or mass
# focused --> VERB | VBN --> verb, past participle
# on --> ADP | IN --> conjunction, subordinating or preposition
# data --> NOUN | NN --> noun, singular or mass
# science --> NOUN | NN --> noun, singular or mass
# artificial --> ADJ | JJ --> adjective (English), other noun-modifier (Chinese)
# intelligence --> NOUN | NN --> noun, singular or mass
# machine --> NOUN | NN --> noun, singular or mass
# learning --> NOUN | NN --> noun, singular or mass
# and --> CCONJ | CC --> conjunction, coordinating
# data --> NOUN | NN --> noun, singular or mass
# analytics --> NOUN | NNS --> noun, plural
# They --> PRON | PRP --> pronoun, personal
# offer --> VERB | VBP --> verb, non-3rd person singular present
# online --> ADJ | JJ --> adjective (English), other noun-modifier (Chinese)
# courses --> NOUN | NNS --> noun, plural
# consulting --> VERB | VBG --> verb, gerund or present participle
# services --> NOUN | NNS --> noun, plural
# and --> CCONJ | CC --> conjunction, coordinating
# job --> NOUN | NN --> noun, singular or mass
# ready --> ADJ | JJ --> adjective (English), other noun-modifier (Chinese)
# bootcamps --> NOUN | NNS --> noun, plural
# to --> PART | TO --> infinitival "to"
# help --> VERB | VB --> verb, base form
# individuals --> NOUN | NNS --> noun, plural
# gain --> VERB | VB --> verb, base form
# skills --> NOUN | NNS --> noun, plural
# and --> CCONJ | CC --> conjunction, coordinating
# knowledge --> NOUN | NN --> noun, singular or mass
# in --> ADP | IN --> conjunction, subordinating or preposition
# these --> DET | DT --> determiner
# areas --> NOUN | NNS --> noun, plural
# Their --> PRON | PRP$ --> pronoun, possessive
# goal --> NOUN | NN --> noun, singular or mass
# is --> AUX | VBZ --> verb, 3rd person singular present
# to --> PART | TO --> infinitival "to"
# make --> VERB | VB --> verb, base form
# data --> NOUN | NNS --> noun, plural
# science --> NOUN | NN --> noun, singular or mass
# accessible --> ADJ | JJ --> adjective (English), other noun-modifier (Chinese)
# and --> CCONJ | CC --> conjunction, coordinating
# empower --> VERB | VB --> verb, base form
# individuals --> NOUN | NNS --> noun, plural
# to --> PART | TO --> infinitival "to"
# leverage --> VERB | VB --> verb, base form
# data --> NOUN | NNS --> noun, plural
# for --> ADP | IN --> conjunction, subordinating or preposition
# better --> ADJ | JJR --> adjective, comparative
# decisions --> NOUN | NNS --> noun, plural
# and --> CCONJ | CC --> conjunction, coordinating
# careers --> NOUN | NNS --> noun, plural

# %% [markdown]
# **Following Basic Prep**

# %%
import string

# %%
exclude_Punctuation=string.punctuation

# %%
def rmv_Punctuation(text):
    for i in exclude_Punctuation:
        text= text.replace(i,"")
    return text

# %%
paragaph1 = """Data Solution-360 is a consulting company and online learning platform focused on data science, 
artificial intelligence, machine learning, and data analytics etc . 
They offer online courses, consulting services, and job-ready bootcamps to help individuals gain skills and knowledge in 
these areas. Their goal is to make data science accessible and empower individuals to leverage data for better decisions 
and careers. """

# %%
new_doc=rmv_Punctuation(paragaph1)

# %%
new_docx=nlp(new_doc)

# %%
for words in new_docx:
    print(words, "-->" , words.pos_ , "|" , words.tag_ ,"-->" , spacy.explain(words.tag_))
# Out:
# Data --> NOUN | NNS --> noun, plural
# Solution360 --> NUM | CD --> cardinal number
# is --> AUX | VBZ --> verb, 3rd person singular present
# a --> DET | DT --> determiner
# consulting --> VERB | VBG --> verb, gerund or present participle
# company --> NOUN | NN --> noun, singular or mass
# and --> CCONJ | CC --> conjunction, coordinating
# online --> ADJ | JJ --> adjective (English), other noun-modifier (Chinese)
# learning --> VERB | VBG --> verb, gerund or present participle
# platform --> NOUN | NN --> noun, singular or mass
# focused --> VERB | VBN --> verb, past participle
# on --> ADP | IN --> conjunction, subordinating or preposition
# data --> NOUN | NN --> noun, singular or mass
# science --> NOUN | NN --> noun, singular or mass
#
#  --> SPACE | _SP --> whitespace
# artificial --> ADJ | JJ --> adjective (English), other noun-modifier (Chinese)
# intelligence --> NOUN | NN --> noun, singular or mass
# machine --> NOUN | NN --> noun, singular or mass
# learning --> NOUN | NN --> noun, singular or mass
# and --> CCONJ | CC --> conjunction, coordinating
# data --> NOUN | NN --> noun, singular or mass
# analytics --> NOUN | NNS --> noun, plural
# etc --> X | FW --> foreign word
#
#  --> SPACE | _SP --> whitespace
# They --> PRON | PRP --> pronoun, personal
# offer --> VERB | VBP --> verb, non-3rd person singular present
# online --> ADJ | JJ --> adjective (English), other noun-modifier (Chinese)
# courses --> NOUN | NNS --> noun, plural
# consulting --> NOUN | NN --> noun, singular or mass
# services --> NOUN | NNS --> noun, plural
# and --> CCONJ | CC --> conjunction, coordinating
# jobready --> ADJ | JJ --> adjective (English), other noun-modifier (Chinese)
# bootcamps --> NOUN | NNS --> noun, plural
# to --> PART | TO --> infinitival "to"
# help --> VERB | VB --> verb, base form
# individuals --> NOUN | NNS --> noun, plural
# gain --> VERB | VB --> verb, base form
# skills --> NOUN | NNS --> noun, plural
# and --> CCONJ | CC --> conjunction, coordinating
# knowledge --> NOUN | NN --> noun, singular or mass
# in --> ADP | IN --> conjunction, subordinating or preposition
#
#  --> SPACE | _SP --> whitespace
# these --> DET | DT --> determiner
# areas --> NOUN | NNS --> noun, plural
# Their --> PRON | PRP$ --> pronoun, possessive
# goal --> NOUN | NN --> noun, singular or mass
# is --> AUX | VBZ --> verb, 3rd person singular present
# to --> PART | TO --> infinitival "to"
# make --> VERB | VB --> verb, base form
# data --> NOUN | NNS --> noun, plural
# science --> NOUN | NN --> noun, singular or mass
# accessible --> ADJ | JJ --> adjective (English), other noun-modifier (Chinese)
# and --> CCONJ | CC --> conjunction, coordinating
# empower --> VERB | VB --> verb, base form
# individuals --> NOUN | NNS --> noun, plural
# to --> PART | TO --> infinitival "to"
# leverage --> VERB | VB --> verb, base form
# data --> NOUN | NNS --> noun, plural
# for --> ADP | IN --> conjunction, subordinating or preposition
# better --> ADJ | JJR --> adjective, comparative
# decisions --> NOUN | NNS --> noun, plural
#
#  --> SPACE | _SP --> whitespace
# and --> CCONJ | CC --> conjunction, coordinating
# careers --> NOUN | NNS --> noun, plural
