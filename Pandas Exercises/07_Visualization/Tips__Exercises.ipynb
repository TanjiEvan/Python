# %% [markdown]
# # Tips

# %% [markdown]
# ### Introduction:
#
# This exercise was created based on the tutorial and documentation from [Seaborn](https://stanford.edu/~mwaskom/software/seaborn/index.html)
# The dataset being used is tips from Seaborn.
#
# ### Step 1. Import the necessary libraries:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv'
tips = pd.read_csv(url)

tips.head()
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %%
del tips["Unnamed: 0"]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
plt.figure(figsize=(12,6))
sns.histplot(data=tips,x="total_bill",kde=True)
plt.show()

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
sns.scatterplot(data=tips,x="total_bill",y="tip",edgecolor="black")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.jointplot(x ="total_bill", y ="tip", data = tips)

# %% [markdown]
# ### Step 7.  Create one image with the relationship of total_bill, tip and size.
# #### Hint: It is just one function.

# %% [markdown]
# pairplot shows visualization of numerical col of the dataset

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,corner=True)

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
sns.scatterplot(data=tips,x="day",y="total_bill",edgecolor="black")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize=(10, 6))
sns.stripplot(x='day', y='total_bill', data=tips,jitter=True)
plt.title('Strip Plot of Total Bill Values by Day')
plt.show()

# %% [markdown]
# Stripplot:
# Purpose: Used to display the distribution of a categorical variable along with a numerical variable.
#
# Scatterplot:
# Purpose: Used to visualize the relationship between two numerical variables.

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
sns.scatterplot(data=tips,x="tip",y="day",edgecolor="black",hue="sex");

# %%
sns.stripplot(x = "tip", y = "day", hue = "sex",edgecolor="black", data = tips, jitter = True);

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
sns.boxplot(x = "day", y = "total_bill", hue = "time", data = tips);

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g = sns.FacetGrid(tips, col = "time")

# %%
g = sns.FacetGrid(tips, row = "time")

# %%
g = sns.FacetGrid(tips, col = "time")
g.map(plt.hist, "tip");

# %%
g = sns.FacetGrid(data=tips, col='time')
g = g.map(plt.hist, "tip",edgecolor="black")
g.add_legend();

plt.subplots_adjust(hspace= 0.4, wspace=0.5);

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %%
g = sns.FacetGrid(data=tips, col='sex',hue="smoker")
g = g.map(plt.scatter, "total_bill","tip",edgecolor="black")
g.add_legend();

plt.subplots_adjust(hspace= 0.4, wspace=0.5);

# %%
g = sns.FacetGrid(tips, col = "sex", hue = "smoker")
g.map(plt.scatter, "total_bill", "tip", alpha =.7)

g.add_legend();

# %% [markdown]
# ### BONUS: Create your own question and answer it using a graph.
