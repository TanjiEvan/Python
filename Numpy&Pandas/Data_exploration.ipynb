# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Check Working Directory

# %%
pwd()
# Out:
# 'c:\\Users\\SPPL IT\\Desktop\\Study\\Python\\Numpy&Pandas'

# %% [markdown]
# ## Importing Dataset

# %%
df = pd.read_csv('tips.csv') ##If dataset in same directory
df
# Out:
#     This is a cafe Bill Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0            total_bill        tip        sex     smoker        day
# 1                 16.99       1.01     Female         No        Sun
# 2                 10.34       1.66       Male         No        Sun
# 3                 21.01        3.5       Male         No        Sun
# 4                 23.68       3.31       Male         No        Sun
# ..                  ...        ...        ...        ...        ...
# 240               29.03       5.92       Male         No        Sat
# 241               27.18          2     Female        Yes        Sat
# 242               22.67          2       Male        Yes        Sat
# 243               17.82       1.75       Male         No        Sat
# 244               18.78          3     Female         No       Thur
#
#     Unnamed: 5 Unnamed: 6        Unnamed: 7          Unnamed: 8 Unnamed: 9  \
# ...

# %%
df = pd.read_csv('tips.csv' ,skiprows=1) ##To Skip The Heading

# %%
df1=pd.read_csv('tips.csv' ,skiprows=1, nrows=6)  ##if we need specific rows
df1
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
#
#            Payer Name     CC Number Payment ID
# 0  Christy Cunningham  3.560000e+15    Sun2959
# 1      Douglas Tucker  4.480000e+15    Sun4608
# 2      Travis Walters  6.010000e+15    Sun4458
# 3    Nathaniel Harris  4.680000e+15    Sun5260
# 4        Tonya Carter  4.830000e+15    Sun2251
# 5          Erik Smith  2.130000e+14    Sun9679

# %%
df.head() ##By default shows first 5 rows
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name     CC Number Payment ID
# 0  Christy Cunningham  3.560000e+15    Sun2959
# 1      Douglas Tucker  4.480000e+15    Sun4608
# 2      Travis Walters  6.010000e+15    Sun4458
# 3    Nathaniel Harris  4.680000e+15    Sun5260
# 4        Tonya Carter  4.830000e+15    Sun2251

# %%
df.tail() #by default shows last 5 rows
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name     CC Number Payment ID
# 239    Michael Avila  5.300000e+15    Sat2657
# 240   Monica Sanders  3.510000e+15    Sat1766
# 241       Keith Wong  6.010000e+15    Sat3880
# 242     Dennis Dixon  4.380000e+12      Sat17
# 243  Michelle Hardin  3.510000e+15    Thur672

# %%
df.head(3) ##If we define (), it will show as many rows as that are defined in ()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name     CC Number Payment ID
# 0  Christy Cunningham  3.560000e+15    Sun2959
# 1      Douglas Tucker  4.480000e+15    Sun4608
# 2      Travis Walters  6.010000e+15    Sun4458

# %%
df.info() ##shows all info of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    float64
#  10  Payment ID        244 non-null    object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 21.1+ KB

# %%
df.sample() ##picks a row by random
# Out:
#     total_bill  tip   sex smoker   day   time  size  price_per_person  \
# 80       19.44  3.0  Male    Yes  Thur  Lunch     2              9.72
#
#       Payer Name     CC Number Payment ID
# 80  Louis Torres  3.880000e+13   Thur6453

# %%
df.shape ##tells the size of dataframe
# Out:
# (244, 11)

# %%
df["Payer Name" ] ##Looking info of specific col
# Out:
# 0      Christy Cunningham
# 1          Douglas Tucker
# 2          Travis Walters
# 3        Nathaniel Harris
# 4            Tonya Carter
#               ...
# 239         Michael Avila
# 240        Monica Sanders
# 241            Keith Wong
# 242          Dennis Dixon
# 243       Michelle Hardin
# Name: Payer Name, Length: 244, dtype: object

# %%
df[["total_bill","sex","tip"]] ##for checking multi variate use list of list
# Out:
#      total_bill     sex   tip
# 0         16.99  Female  1.01
# 1         10.34    Male  1.66
# 2         21.01    Male  3.50
# 3         23.68    Male  3.31
# 4         24.59  Female  3.61
# ..          ...     ...   ...
# 239       29.03    Male  5.92
# 240       27.18  Female  2.00
# 241       22.67    Male  2.00
# 242       17.82    Male  1.75
# 243       18.78  Female  3.00
#
# [244 rows x 3 columns]

# %%
first_five_rows=df[["total_bill","sex","tip"]]
first_five_rows.head(5)
# Out:
#    total_bill     sex   tip
# 0       16.99  Female  1.01
# 1       10.34    Male  1.66
# 2       21.01    Male  3.50
# 3       23.68    Male  3.31
# 4       24.59  Female  3.61

# %%
df[["total_bill","sex","tip"]].head(5)
# Out:
#    total_bill     sex   tip
# 0       16.99  Female  1.01
# 1       10.34    Male  1.66
# 2       21.01    Male  3.50
# 3       23.68    Male  3.31
# 4       24.59  Female  3.61

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.iloc[:,[0,1,2]]
# Out:
#      total_bill   tip     sex
# 0         16.99  1.01  Female
# 1         10.34  1.66    Male
# 2         21.01  3.50    Male
# 3         23.68  3.31    Male
# 4         24.59  3.61  Female
# ..          ...   ...     ...
# 239       29.03  5.92    Male
# 240       27.18  2.00  Female
# 241       22.67  2.00    Male
# 242       17.82  1.75    Male
# 243       18.78  3.00  Female
#
# [244 rows x 3 columns]

# %%
df.iloc[1:5,[0,1,2]]
# Out:
#    total_bill   tip     sex
# 1       10.34  1.66    Male
# 2       21.01  3.50    Male
# 3       23.68  3.31    Male
# 4       24.59  3.61  Female

# %%
df.iloc[1:5,:]
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#          Payer Name     CC Number Payment ID
# 1    Douglas Tucker  4.480000e+15    Sun4608
# 2    Travis Walters  6.010000e+15    Sun4458
# 3  Nathaniel Harris  4.680000e+15    Sun5260
# 4      Tonya Carter  4.830000e+15    Sun2251

# %%
df.iloc[1:5,0:5]
# Out:
#    total_bill   tip     sex smoker  day
# 1       10.34  1.66    Male     No  Sun
# 2       21.01  3.50    Male     No  Sun
# 3       23.68  3.31    Male     No  Sun
# 4       24.59  3.61  Female     No  Sun

# %%
tips_over_5=df[df["tip"]>5] ##Conditional 
tips_over_5
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 44        30.40   5.60    Male     No   Sun  Dinner     4              7.60
# 47        32.40   6.00    Male     No   Sun  Dinner     4              8.10
# 52        34.81   5.20  Female     No   Sun  Dinner     4              8.70
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 85        34.83   5.17  Female     No  Thur   Lunch     4              8.71
# 88        24.71   5.85    Male     No  Thur   Lunch     2             12.36
# 116       29.93   5.07    Male     No   Sun  Dinner     4              7.48
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 155       29.85   5.14  Female     No   Sun  Dinner     5              5.97
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# ...

# %%
filtering_cond=df["tip"] > 5  ##Condtional_another_method
tips_over_5=df[filtering_cond]
tips_over_5
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 44        30.40   5.60    Male     No   Sun  Dinner     4              7.60
# 47        32.40   6.00    Male     No   Sun  Dinner     4              8.10
# 52        34.81   5.20  Female     No   Sun  Dinner     4              8.70
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 85        34.83   5.17  Female     No  Thur   Lunch     4              8.71
# 88        24.71   5.85    Male     No  Thur   Lunch     2             12.36
# 116       29.93   5.07    Male     No   Sun  Dinner     4              7.48
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 155       29.85   5.14  Female     No   Sun  Dinner     5              5.97
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# ...

# %%
filtering_cond=(df["tip"] > 5) & (df["day"]=="Sat")  ##Multiple_Condtional
tips_over_5=df[filtering_cond]
tips_over_5
# Out:
#      total_bill    tip     sex smoker  day    time  size  price_per_person  \
# 23        39.42   7.58    Male     No  Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No  Sat  Dinner     4             12.07
# 170       50.81  10.00    Male    Yes  Sat  Dinner     3             16.94
# 211       25.89   5.16    Male    Yes  Sat  Dinner     4              6.47
# 212       48.33   9.00    Male     No  Sat  Dinner     4             12.08
# 214       28.17   6.50  Female    Yes  Sat  Dinner     3              9.39
# 239       29.03   5.92    Male     No  Sat  Dinner     3              9.68
#
#           Payer Name     CC Number Payment ID
# 23    Lance Peterson  3.540000e+15     Sat239
# 59       Brian Ortiz  6.600000e+15    Sat8139
# 170    Gregory Clark  5.470000e+15    Sat1954
# 211   Christopher Li  6.010000e+15    Sat6735
# 212  Alex Williamson  6.760000e+11    Sat4590
# 214  Marissa Jackson  4.920000e+15    Sat3374
# ...

# %% [markdown]
# ## Statistical

# %%
df["tip"].min()
# Out:
# 1.0

# %%
df["tip"].max()
# Out:
# 10.0

# %%
df.describe() ##Statistical_Info
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563313e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369139e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040000e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525000e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.552500e+15
# max     50.810000   10.000000    6.000000         20.270000  6.600000e+15

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563313e+15  2.369139e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040000e+13  3.525000e+15  4.552500e+15  6.600000e+15

# %%
df["sex"].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df["Payer Name"].unique()
# Out:
# array(['Christy Cunningham', 'Douglas Tucker', 'Travis Walters',
#        'Nathaniel Harris', 'Tonya Carter', 'Erik Smith',
#        'Kristopher Johnson', 'Robert Buck', 'Joseph Mcdonald',
#        'Jerome Abbott', 'William Riley', 'Diane Macias',
#        'Chad Harrington', 'Joshua Jones', 'Vanessa Jones',
#        'Matthew Reilly', 'Elizabeth Foster', 'John Pittman',
#        'Laura Martinez', 'Timothy Oneal', 'Thomas Rice',
#        'Natalie Gardner', 'Ashley Shelton', 'Lance Peterson',
#        'Christopher Ross', 'Robert Perkins', 'Kyle Avery',
#        'Patrick Barber', 'David Collier', 'Melinda Murphy', 'Grant Hall',
#        'Danny Santiago', 'Amanda Wilson', 'Amber Francis',
#        'Jacob Castillo', 'Joseph Mullins', 'William Ford', 'Erin Lewis',
#        'Brandon Bradley', 'Mr. Brandon Berry', 'Adam Edwards',
#        'David Boyer', 'Bryan Brown', 'Christopher Spears', 'Todd Cooper',
#        'Richard Fitzgerald', 'Joshua Gilmore', 'James Barnes',
# ...

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %% [markdown]
# ## Creating a new Col

# %% [markdown]
# > <df.loc:> Selects rows and columns by labels or boolean array.
#
# > <df.iloc:> Selects rows and columns by integer position (index-based).

# %%
df.loc[:, "total_amt"] = df["total_bill"] + df["tip"]

# %%
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7       26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8       15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9       14.78  3.23    Male     No  Sun  Dinner     2              7.39
#
#            Payer Name     CC Number Payment ID  total_amt
# 0  Christy Cunningham  3.560000e+15    Sun2959      18.00
# 1      Douglas Tucker  4.480000e+15    Sun4608      12.00
# ...

# %%
df["total_amt"] =np.round(df["total_amt"]) ##Formating

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name     CC Number Payment ID  total_amt
# 0  Christy Cunningham  3.560000e+15    Sun2959       18.0
# 1      Douglas Tucker  4.480000e+15    Sun4608       12.0
# 2      Travis Walters  6.010000e+15    Sun4458       25.0
# 3    Nathaniel Harris  4.680000e+15    Sun5260       27.0
# 4        Tonya Carter  4.830000e+15    Sun2251       28.0

# %%
df.drop(["total_amt"],axis=1) #deleting col
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name     CC Number Payment ID
# ...

# %%
df.drop(index=range(0,21)) ##Dropping rows
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 21        20.29  2.75  Female     No   Sat  Dinner     2             10.14
# 22        15.77  2.23  Female     No   Sat  Dinner     2              7.88
# 23        39.42  7.58    Male     No   Sat  Dinner     4              9.86
# 24        19.82  3.18    Male     No   Sat  Dinner     2              9.91
# 25        17.81  2.34    Male     No   Sat  Dinner     4              4.45
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#            Payer Name     CC Number Payment ID  total_amt
# ...

# %% [markdown]
# ## Exporting Dataset

# %%
df.loc[:, "total_amt"] = df["total_bill"] + df["tip"] ##Adding again to try export

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name     CC Number Payment ID  total_amt
# 0  Christy Cunningham  3.560000e+15    Sun2959      18.00
# 1      Douglas Tucker  4.480000e+15    Sun4608      12.00
# 2      Travis Walters  6.010000e+15    Sun4458      24.51
# 3    Nathaniel Harris  4.680000e+15    Sun5260      26.99
# 4        Tonya Carter  4.830000e+15    Sun2251      28.20

# %%
df.to_csv("updated_tips.csv" , index=False) ##Dataset export
