# %%
import pandas as pd

df = pd.read_csv("dataset.csv")
df.head()
# Out:
#          f1        f2        f3        f4        f5        f6        f7  \
# 0 -0.924357 -0.326536 -1.875007 -1.780626 -0.630143  0.788204  2.792209
# 1  0.001795 -1.285599 -0.726774  0.385711  0.891863  0.599451 -0.140553
# 2  0.956702  2.319330 -0.705012  0.081829  0.330880  0.838491  2.493000
# 3 -0.982294  0.190424  1.082691  0.714610 -1.907808  0.224216  0.156973
# 4 -0.057061 -0.592465 -2.850030 -1.935430  2.002427 -1.012644  1.059950
#
#          f8        f9       f10  ...      f142      f143      f144      f145  \
# 0 -0.772192 -0.450994  0.400000  ...  0.968645 -0.702053 -0.327662 -0.392108
# 1 -0.761760  0.117707  0.333231  ...  0.856399  0.214094 -1.245739  0.173181
# 2  1.227669 -0.785989 -0.920674  ... -0.493001 -0.589365  0.849602  0.357015
# 3  0.556553  0.058984 -1.397118  ...  0.491919 -1.320233  1.831459  1.179440
# 4 -1.000629  0.141596 -0.642776  ...  1.479944  0.077368 -0.861284  1.523124
#
#        f146      f147      f148      f149      f150      target
# ...

# %%
X = df.drop("target", axis=1)
Y = df["target"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression()
linear_model.fit(X_train, Y_train)

linear_score = linear_model.score(X_test, Y_test) ## Provides R^2 value
print("Linear Regression Score:", linear_score)
# Out:
# Linear Regression Score: 0.7407699448090973

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_pred = linear_model.predict(X_test)
mse = mean_squared_error(Y_test, y_pred)
r2 = r2_score(Y_test, y_pred)
mse, r2
## The r2 values are same !!
# Out:
# (np.float64(4256.831364853606), 0.7407699448090973)

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso

lasso_model = Lasso(alpha=1.0) ## Lambda=1
lasso_model.fit(X_train, Y_train)

lasso_score = lasso_model.score(X_test, Y_test)
print("Lasso Regression Score:", lasso_score)
# Out:
# Lasso Regression Score: 0.9901476660336155

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Ridge

ridge_model = Ridge(alpha=1.0)
ridge_model.fit(X_train, Y_train)

ridge_score = ridge_model.score(X_test, Y_test)
print("Ridge Regression Score:", ridge_score)
# Out:
# Ridge Regression Score: 0.9462671341742038

# %%
print("Linear Regression Coefficients:", linear_model.coef_)
# Out:
# Linear Regression Coefficients: [ 30.5529686  -37.70086962  14.09337927   0.71566209   3.8566754
#  -31.16888952  53.71953251  93.72495217 -31.71960855 -11.49490186
#  -35.78722715  40.53513664   3.53617525  -2.20577721 -15.23551139
#    6.71447561  20.38611051 -17.35611668  42.70993628  66.06326814
#  -39.68255197   5.78358348  46.10986893  31.64489999  -2.33865303
#   -4.26549023   0.5998225    3.92014716  -5.02664711   3.94129106
#    3.90755131  -7.36619782  86.83537525   0.39558515  -3.2889072
#   -3.08485505   4.38489388   5.241339    -3.52399715   9.1755556
#    6.14142643   5.4917002   -0.84412887  -0.74377036  -3.00423892
#   -1.32249012  -5.36477714   3.10653294  -1.05103729   1.61577871
#  -28.24384403  38.61364017   9.45828103  -2.624556    25.88892706
#   23.06717591 -54.0885213  -28.36846811  19.23318428  13.36961028
#   21.39528237 -39.32777672 -10.98146293  -3.83224547  12.45226688
#   -5.3159486   12.78709719  18.0462138  -40.89040707   2.07874904
# ...

# %%
print("Lasso Regression Coefficients:", lasso_model.coef_)
## 0 means that feature is getting null
# Out:
# Lasso Regression Coefficients: [-0.00000000e+00 -2.44412330e-01  1.97252435e+01  0.00000000e+00
#   3.08713932e+01  0.00000000e+00  0.00000000e+00  5.77703222e+01
#  -7.94713931e-02  0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   3.18993512e+01 -0.00000000e+00  6.25100957e+00  7.55194924e+01
#  -0.00000000e+00  7.98983405e+00  0.00000000e+00  7.48130970e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00  0.00000000e+00 -2.36105000e-01
#   7.35506860e+01 -0.00000000e+00 -0.00000000e+00  3.03345241e+00
#  -0.00000000e+00  0.00000000e+00 -0.00000000e+00  0.00000000e+00
#  -5.96641418e-01 -0.00000000e+00  7.18814788e-01  0.00000000e+00
#   2.49000405e-01  2.30764916e-01 -0.00000000e+00 -0.00000000e+00
#  -5.67191297e-01  0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   7.74812026e+00  0.00000000e+00  0.00000000e+00  6.50440152e-01
# ...

# %%
print("Ridge Regression Coefficients:", ridge_model.coef_)
# Out:
# Ridge Regression Coefficients: [ 2.67063081e-01 -1.21993222e+01  1.14056329e+01 -1.10158570e+00
#   2.09711681e+01 -1.48760737e+00  4.54697294e+00  3.99158360e+01
#  -7.57051013e+00  4.03547747e+00  4.57421758e+00 -1.18402866e+00
#  -5.95509311e+00  8.80853280e+00 -2.07233431e+00  8.12731648e-01
#   1.41735528e+01  1.40528390e+00  4.85652808e+00  5.27024543e+01
#  -2.43489666e+00 -1.77585135e+00 -3.46313496e+00  9.60519173e+00
#   5.06271364e+00 -4.70582094e+00 -3.20294322e-01 -1.20005270e+00
#  -1.54732927e+00  4.47696843e+00  8.97119964e-01 -3.64175682e+00
#   7.14356364e+01  9.81887010e-01 -2.21083244e+00  4.46587840e+00
#   1.91374068e+00 -7.26786159e-01  3.66076448e+00  2.25704879e+00
#  -4.71306514e+00  2.68670970e+00  4.30144485e+00 -3.82294765e-01
#   2.50617243e+00  3.19699894e+00  1.03599106e-01 -2.11202085e+00
#  -2.23914473e+00 -1.30390022e+00 -2.65247303e-01  7.11087500e+00
#   1.57647901e+01  5.39335760e-01  9.24451631e+00  3.93023329e+00
# ...
