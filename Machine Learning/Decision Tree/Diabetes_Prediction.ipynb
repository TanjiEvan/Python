# %% [markdown]
# ## Decision Tree Regressor

# %%
from sklearn.datasets import load_diabetes

# %%
dataset=load_diabetes()

# %%
print(dataset['DESCR'])
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
#     - s6      glu, blood sugar level
#
# Note: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times the square root of `n_samples` (i.e. the sum of squares of each column totals 1).
#
# Source URL:
# https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html
#
# For more information see:
# Bradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.
# (https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)

# %%
import pandas as pd
df_diabetes=pd.DataFrame(dataset.data,columns=['age',
  'sex',
  'bmi',
  'bp',
  's1',
  's2',
  's3',
  's4',
  's5',
  's6'])
df_diabetes.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
X=df_diabetes
y=dataset['target']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=10)

# %%
## Correlation 

X_train.corr()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# age  1.000000  0.197408  0.198359  0.394903  0.238375  0.192920 -0.128403
# sex  0.197408  1.000000  0.108261  0.221914  0.057674  0.180315 -0.379464
# bmi  0.198359  0.108261  1.000000  0.356324  0.226047  0.248146 -0.395021
# bp   0.394903  0.221914  0.356324  1.000000  0.238295  0.165632 -0.192505
# s1   0.238375  0.057674  0.226047  0.238295  1.000000  0.872781  0.006313
# s2   0.192920  0.180315  0.248146  0.165632  0.872781  1.000000 -0.265114
# s3  -0.128403 -0.379464 -0.395021 -0.192505  0.006313 -0.265114  1.000000
# s4   0.227110  0.324882  0.412826  0.249141  0.559626  0.684840 -0.754616
# s5   0.314151  0.150956  0.435505  0.420236  0.566312  0.325759 -0.370523
# s6   0.351570  0.193322  0.358273  0.368882  0.356280  0.315890 -0.297055
#
#            s4        s5        s6
# age  0.227110  0.314151  0.351570
# sex  0.324882  0.150956  0.193322
# bmi  0.412826  0.435505  0.358273
# bp   0.249141  0.420236  0.368882
# s1   0.559626  0.566312  0.356280
# s2   0.684840  0.325759  0.315890
# s3  -0.754616 -0.370523 -0.297055
# s4   1.000000  0.609983  0.436311
# s5   0.609983  1.000000  0.490970
# s6   0.436311  0.490970  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
sns.heatmap(X_train.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.tree import DecisionTreeRegressor
regressor=DecisionTreeRegressor()
regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# but this may not be enough as we might face overfittng

# %% [markdown]
# ## Hyperparameter Tuning

# %%
param={
    'criterion':['squared_error','friedman_mse','absolute_error'],
    'splitter':['best','random'],
    'max_depth':[1,2,3,4,5,10,15,20,25],
    'max_features':['auto','sqrt','log2']
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
regressor=DecisionTreeRegressor()

# %%
grid=GridSearchCV(regressor,param_grid=param,cv=5,scoring='neg_mean_squared_error')

# %%
import warnings
warnings.filterwarnings('ignore')
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error'],
#                          'max_depth': [1, 2, 3, 4, 5, 10, 15, 20, 25],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='neg_mean_squared_error')

# %%
grid.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 5,
#  'max_features': 'log2',
#  'splitter': 'random'}

# %%
y_pred=grid.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
# Out:
# 0.045468575719725624
# 58.724229598254446
# 6039.960902716883

# %%
selectedmodel=DecisionTreeRegressor(criterion='squared_error',max_depth=5,max_features='log2',splitter='random')

# %%
selectedmodel.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=5, max_features='log2', splitter='random')

# %%
##Visualize the Decision Tree
import matplotlib.pyplot as plt
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(selectedmodel,filled=True)
# Out:
# [Text(0.51875, 0.9166666666666666, 'x[4] <= 0.04\nsquared_error = 5757.456\nsamples = 309\nvalue = 152.738'),
#  Text(0.26666666666666666, 0.75, 'x[0] <= 0.022\nsquared_error = 5958.847\nsamples = 249\nvalue = 147.57'),
#  Text(0.3927083333333333, 0.8333333333333333, 'True  '),
#  Text(0.13333333333333333, 0.5833333333333334, 'x[2] <= -0.014\nsquared_error = 5551.766\nsamples = 163\nvalue = 132.429'),
#  Text(0.06666666666666667, 0.4166666666666667, 'x[9] <= 0.022\nsquared_error = 2165.802\nsamples = 82\nvalue = 98.317'),
#  Text(0.03333333333333333, 0.25, 'x[1] <= -0.04\nsquared_error = 2303.18\nsamples = 73\nvalue = 99.534'),
#  Text(0.016666666666666666, 0.08333333333333333, 'squared_error = 2357.154\nsamples = 52\nvalue = 106.0'),
#  Text(0.05, 0.08333333333333333, 'squared_error = 1809.678\nsamples = 21\nvalue = 83.524'),
#  Text(0.1, 0.25, 'x[5] <= -0.028\nsquared_error = 942.025\nsamples = 9\nvalue = 88.444'),
#  Text(0.08333333333333333, 0.08333333333333333, 'squared_error = 441.0\nsamples = 2\nvalue = 114.0'),
#  Text(0.11666666666666667, 0.08333333333333333, 'squared_error = 845.265\nsamples = 7\nvalue = 81.143'),
#  Text(0.2, 0.4166666666666667, 'x[2] <= 0.153\nsquared_error = 6608.949\nsamples = 81\nvalue = 166.963'),
#  Text(0.16666666666666666, 0.25, 'x[8] <= -0.028\nsquared_error = 6288.898\nsamples = 79\nvalue = 163.747'),
#  Text(0.15, 0.08333333333333333, 'squared_error = 3495.331\nsamples = 23\nvalue = 109.87'),
#  Text(0.18333333333333332, 0.08333333333333333, 'squared_error = 5754.395\nsamples = 56\nvalue = 185.875'),
#  Text(0.23333333333333334, 0.25, 'x[0] <= -0.045\nsquared_error = 2704.0\nsamples = 2\nvalue = 294.0'),
#  Text(0.21666666666666667, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 346.0'),
#  Text(0.25, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 242.0'),
#  Text(0.4, 0.5833333333333334, 'x[8] <= -0.023\nsquared_error = 5472.382\nsamples = 86\nvalue = 176.267'),
#  Text(0.3333333333333333, 0.4166666666666667, 'x[3] <= 0.015\nsquared_error = 2771.504\nsamples = 22\nvalue = 131.364'),
#  Text(0.3, 0.25, 'x[7] <= 0.058\nsquared_error = 1671.23\nsamples = 14\nvalue = 115.643'),
#  Text(0.2833333333333333, 0.08333333333333333, 'squared_error = 1672.021\nsamples = 12\nvalue = 121.75'),
#  Text(0.31666666666666665, 0.08333333333333333, 'squared_error = 100.0\nsamples = 2\nvalue = 79.0'),
#  Text(0.36666666666666664, 0.25, 'x[5] <= -0.02\nsquared_error = 3507.609\nsamples = 8\nvalue = 158.875'),
#  Text(0.35, 0.08333333333333333, 'squared_error = 342.25\nsamples = 2\nvalue = 200.5'),
#  Text(0.38333333333333336, 0.08333333333333333, 'squared_error = 3792.667\nsamples = 6\nvalue = 145.0'),
#  Text(0.4666666666666667, 0.4166666666666667, 'x[2] <= 0.033\nsquared_error = 5469.427\nsamples = 64\nvalue = 191.703'),
#  Text(0.43333333333333335, 0.25, 'x[7] <= 0.018\nsquared_error = 3709.391\nsamples = 41\nvalue = 168.78'),
#  Text(0.4166666666666667, 0.08333333333333333, 'squared_error = 3153.992\nsamples = 23\nvalue = 155.087'),
#  Text(0.45, 0.08333333333333333, 'squared_error = 3873.312\nsamples = 18\nvalue = 186.278'),
#  Text(0.5, 0.25, 'x[7] <= -0.019\nsquared_error = 6000.507\nsamples = 23\nvalue = 232.565'),
#  Text(0.48333333333333334, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 70.0'),
#  Text(0.5166666666666667, 0.08333333333333333, 'squared_error = 5017.407\nsamples = 22\nvalue = 239.955'),
#  Text(0.7708333333333334, 0.75, 'x[8] <= 0.073\nsquared_error = 4350.95\nsamples = 60\nvalue = 174.183'),
#  Text(0.6447916666666667, 0.8333333333333333, '  False'),
#  Text(0.6666666666666666, 0.5833333333333334, 'x[6] <= 0.063\nsquared_error = 3579.954\nsamples = 45\nvalue = 159.156'),
#  Text(0.6, 0.4166666666666667, 'x[8] <= 0.066\nsquared_error = 3279.899\nsamples = 40\nvalue = 167.725'),
#  Text(0.5666666666666667, 0.25, 'x[5] <= 0.116\nsquared_error = 2919.194\nsamples = 36\nvalue = 159.472'),
#  Text(0.55, 0.08333333333333333, 'squared_error = 2801.409\nsamples = 31\nvalue = 161.548'),
#  Text(0.5833333333333334, 0.08333333333333333, 'squared_error = 3457.04\nsamples = 5\nvalue = 146.6'),
#  Text(0.6333333333333333, 0.25, 'x[4] <= 0.058\nsquared_error = 396.5\nsamples = 4\nvalue = 242.0'),
#  Text(0.6166666666666667, 0.08333333333333333, 'squared_error = 81.0\nsamples = 2\nvalue = 224.0'),
#  Text(0.65, 0.08333333333333333, 'squared_error = 64.0\nsamples = 2\nvalue = 260.0'),
#  Text(0.7333333333333333, 0.4166666666666667, 'x[9] <= -0.018\nsquared_error = 693.04\nsamples = 5\nvalue = 90.6'),
#  Text(0.7, 0.25, 'x[7] <= -0.053\nsquared_error = 552.25\nsamples = 2\nvalue = 110.5'),
#  Text(0.6833333333333333, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 87.0'),
#  Text(0.7166666666666667, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 134.0'),
#  Text(0.7666666666666667, 0.25, 'x[8] <= 0.018\nsquared_error = 346.889\nsamples = 3\nvalue = 77.333'),
#  Text(0.75, 0.08333333333333333, 'squared_error = 64.0\nsamples = 2\nvalue = 65.0'),
#  Text(0.7833333333333333, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 102.0'),
#  Text(0.875, 0.5833333333333334, 'x[8] <= 0.08\nsquared_error = 3953.929\nsamples = 15\nvalue = 219.267'),
#  Text(0.8166666666666667, 0.4166666666666667, 'x[2] <= -0.002\nsquared_error = 378.0\nsamples = 3\nvalue = 263.0'),
#  Text(0.8, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 281.0'),
#  Text(0.8333333333333334, 0.25, 'x[0] <= 0.072\nsquared_error = 324.0\nsamples = 2\nvalue = 254.0'),
#  Text(0.8166666666666667, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 272.0'),
#  Text(0.85, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 236.0'),
#  Text(0.9333333333333333, 0.4166666666666667, 'x[9] <= 0.045\nsquared_error = 4250.222\nsamples = 12\nvalue = 208.333'),
#  Text(0.9, 0.25, 'x[1] <= 0.039\nsquared_error = 2898.531\nsamples = 7\nvalue = 173.429'),
#  Text(0.8833333333333333, 0.08333333333333333, 'squared_error = 672.667\nsamples = 3\nvalue = 117.0'),
#  Text(0.9166666666666666, 0.08333333333333333, 'squared_error = 388.688\nsamples = 4\nvalue = 215.75'),
#  Text(0.9666666666666667, 0.25, 'x[0] <= 0.069\nsquared_error = 2048.96\nsamples = 5\nvalue = 257.2'),
#  Text(0.95, 0.08333333333333333, 'squared_error = 2992.889\nsamples = 3\nvalue = 269.333'),
#  Text(0.9833333333333333, 0.08333333333333333, 'squared_error = 81.0\nsamples = 2\nvalue = 239.0')]
